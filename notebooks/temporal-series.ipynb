# %% [markdown]
# # Preparando e processando os dados

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: tzdata>=2022.7 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/bicicletas.csv')

# %%
df.head()
# Out:
#              data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0  2015-01-04 00:00:00       182          3.0               2.0     93.0
# 1  2015-01-04 01:00:00       138          NaN               NaN     93.0
# 2  2015-01-04 02:00:00       134          2.5               2.5     96.5
# 3  2015-01-04 03:00:00        72          2.0               2.0    100.0
# 4  2015-01-04 04:00:00        47          NaN               NaN     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao
# 0               6.0    Nublado     Não           Sim  Inverno
# 1               5.0  Céu limpo     Não           Sim  Inverno
# 2               0.0  Céu limpo     Não           Sim  Inverno
# 3               0.0  Céu limpo     Não           Sim  Inverno
# 4               6.5  Céu limpo     Não           Sim  Inverno

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17429 entries, 0 to 17428
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_hora         17429 non-null  object
#  1   contagem          17429 non-null  int64
#  2   temperatura       17406 non-null  float64
#  3   sensacao_termica  17406 non-null  float64
#  4   umidade           17429 non-null  float64
#  5   velocidade_vento  17429 non-null  float64
#  6   clima             17429 non-null  object
#  7   feriado           17429 non-null  object
#  8   fim_de_semana     17429 non-null  object
#  9   estacao           17429 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (17429, 10)

# %%
df.isnull().sum()
# Out:
# data_hora            0
# contagem             0
# temperatura         23
# sensacao_termica    23
# umidade              0
# velocidade_vento     0
# clima                0
# feriado              0
# fim_de_semana        0
# estacao              0
# dtype: int64

# %%
df['temperatura'] = df['temperatura'].interpolate(method='linear')
df['sensacao_termica'] = df['sensacao_termica'].interpolate(method='linear')

# %%
df.head(10)
# Out:
#              data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0  2015-01-04 00:00:00       182         3.00              2.00     93.0
# 1  2015-01-04 01:00:00       138         2.75              2.25     93.0
# 2  2015-01-04 02:00:00       134         2.50              2.50     96.5
# 3  2015-01-04 03:00:00        72         2.00              2.00    100.0
# 4  2015-01-04 04:00:00        47         2.00              2.00     93.0
# 5  2015-01-04 05:00:00        46         2.00              2.00     93.0
# 6  2015-01-04 06:00:00        51         1.00             -1.00    100.0
# 7  2015-01-04 07:00:00        75         1.00             -1.00    100.0
# 8  2015-01-04 08:00:00       131         1.50             -1.00     96.5
# 9  2015-01-04 09:00:00       301         2.00             -0.50    100.0
#
#    velocidade_vento                 clima feriado fim_de_semana  estacao
# 0               6.0               Nublado     Não           Sim  Inverno
# 1               5.0             Céu limpo     Não           Sim  Inverno
# 2               0.0             Céu limpo     Não           Sim  Inverno
# 3               0.0             Céu limpo     Não           Sim  Inverno
# 4               6.5             Céu limpo     Não           Sim  Inverno
# 5               4.0             Céu limpo     Não           Sim  Inverno
# 6               7.0  Parcialmente nublado     Não           Sim  Inverno
# 7               7.0  Parcialmente nublado     Não           Sim  Inverno
# 8               8.0  Parcialmente nublado     Não           Sim  Inverno
# 9               9.0               Nublado     Não           Sim  Inverno

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %%
duplicatas = df.duplicated(keep=False)

linhas_duplicadas = df[duplicatas]

linhas_duplicadas.sort_values(by='data_hora')
# Out:
#                  data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 519    2015-01-25 16:00:00      1238          8.0               5.0     71.0
# 17422  2015-01-25 16:00:00      1238          8.0               5.0     71.0
# 869    2015-02-09 06:00:00       479          5.0               3.5     87.0
# 17417  2015-02-09 06:00:00       479          5.0               3.5     87.0
# 3655   2015-06-05 18:00:00      3411         23.0              23.0     50.0
# 17425  2015-06-05 18:00:00      3411         23.0              23.0     50.0
# 4167   2015-06-27 02:00:00       337         15.5              15.5     74.5
# 17421  2015-06-27 02:00:00       337         15.5              15.5     74.5
# 4658   2015-07-17 14:00:00      1882         24.5              24.5     44.0
# 17418  2015-07-17 14:00:00      1882         24.5              24.5     44.0
# 17428  2015-08-15 23:00:00       759         17.0              17.0     59.0
# 5360   2015-08-15 23:00:00       759         17.0              17.0     59.0
# 17426  2015-12-12 11:00:00      1100         12.0              12.0     82.0
# 8174   2015-12-12 11:00:00      1100         12.0              12.0     82.0
# 17420  2015-12-12 12:00:00      1308         13.0              13.0     77.0
# 8175   2015-12-12 12:00:00      1308         13.0              13.0     77.0
# 17415  2015-12-27 05:00:00        57         15.0              15.0     72.0
# 8528   2015-12-27 05:00:00        57         15.0              15.0     72.0
# 17427  2016-02-02 17:00:00      2846          8.0               4.5     59.5
# 9428   2016-02-02 17:00:00      2846          8.0               4.5     59.5
# 17414  2016-05-06 03:00:00        77          9.5               9.0     79.0
# 11646  2016-05-06 03:00:00        77          9.5               9.0     79.0
# 12350  2016-06-04 11:00:00      1779         15.5              15.5     85.5
# 17419  2016-06-04 11:00:00      1779         15.5              15.5     85.5
# 12443  2016-06-08 08:00:00      4672         18.0              18.0     83.0
# 17416  2016-06-08 08:00:00      4672         18.0              18.0     83.0
# 17424  2016-12-11 10:00:00      1098          7.5               4.5     87.0
# 16848  2016-12-11 10:00:00      1098          7.5               4.5     87.0
# 17423  2016-12-23 02:00:00        92          7.5               5.5     90.0
# 17128  2016-12-23 02:00:00        92          7.5               5.5     90.0
#
#        velocidade_vento                 clima feriado fim_de_semana    estacao
# 519                18.0               Nublado     Não           Sim    Inverno
# 17422              18.0               Nublado     Não           Sim    Inverno
# 869                 6.5  Parcialmente nublado     Não           Não    Inverno
# 17417               6.5  Parcialmente nublado     Não           Não    Inverno
# 3655               26.0  Parcialmente nublado     Não           Não      Verão
# 17425              26.0  Parcialmente nublado     Não           Não      Verão
# 4167               18.0  Parcialmente nublado     Não           Sim      Verão
# 17421              18.0  Parcialmente nublado     Não           Sim      Verão
# 4658               29.5  Parcialmente nublado     Não           Não      Verão
# 17418              29.5  Parcialmente nublado     Não           Não      Verão
# 17428               6.0             Céu limpo     Não           Sim      Verão
# 5360                6.0             Céu limpo     Não           Sim      Verão
# 17426              20.0            Chuva leve     Não           Sim    Inverno
# 8174               20.0            Chuva leve     Não           Sim    Inverno
# 17420              26.0            Chuva leve     Não           Sim    Inverno
# 8175               26.0            Chuva leve     Não           Sim    Inverno
# 17415              31.0  Parcialmente nublado     Não           Sim    Inverno
# 8528               31.0  Parcialmente nublado     Não           Sim    Inverno
# 17427              23.0  Parcialmente nublado     Não           Não    Inverno
# 9428               23.0  Parcialmente nublado     Não           Não    Inverno
# 17414               6.0             Céu limpo     Não           Não  Primavera
# 11646               6.0             Céu limpo     Não           Não  Primavera
# 12350               8.0               Nublado     Não           Sim      Verão
# 17419               8.0               Nublado     Não           Sim      Verão
# 12443               2.0             Céu limpo     Não           Não      Verão
# 17416               2.0             Céu limpo     Não           Não      Verão
# 17424              16.0             Céu limpo     Não           Sim    Inverno
# 16848              16.0             Céu limpo     Não           Sim    Inverno
# 17423              10.0             Céu limpo     Não           Não    Inverno
# 17128              10.0             Céu limpo     Não           Não    Inverno

# %%
df_limpo = df.drop_duplicates()

# %%
df_limpo.shape
# Out:
# (17414, 10)

# %% [markdown]
# # Explorando os dados numéricos

# %%
df_limpo.describe()
# Out:
#            contagem   temperatura  sensacao_termica       umidade  \
# count  17414.000000  17414.000000      17414.000000  17414.000000
# mean    1143.101642     12.468206         11.521080     72.324954
# std     1085.108068      5.571670          6.614799     14.313186
# min        0.000000     -1.500000         -6.000000     20.500000
# 25%      257.000000      8.000000          6.000000     63.000000
# 50%      844.000000     12.500000         12.500000     74.500000
# 75%     1671.750000     16.000000         16.000000     83.000000
# max     7860.000000     34.000000         34.000000    100.000000
#
#        velocidade_vento
# count      17414.000000
# mean          15.913063
# std            7.894570
# min            0.000000
# 25%           10.000000
# 50%           15.000000
# 75%           20.500000
# max           56.500000

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.23 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: cycler>=0.10 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: six>=1.5 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: packaging>=20.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(df_limpo,x='temperatura', bins=10)
plt.show()

# %%
sns.displot(df_limpo,x='sensacao_termica', bins=10)
plt.show()

# %%
sns.displot(df_limpo,x='umidade', bins=10)
plt.show()

# %%
sns.displot(df_limpo,x='velocidade_vento', bins=10)
plt.show()

# %%
fig, axes = plt.subplots(2,2, figsize=(15,10))

sns.scatterplot(data=df_limpo, x='temperatura',y='contagem', ax=axes[0,0], color="red")
axes[0,0].set_title('Temperatura vs Contagem')


sns.scatterplot(data=df_limpo, x='sensacao_termica',y='contagem', ax=axes[0,1], color="purple")
axes[0,1].set_title('Sensação Térmica vs Contagem')


sns.scatterplot(data=df_limpo, x='umidade',y='contagem', ax=axes[1,0], color="green")
axes[1,0].set_title('Umidade vs Contagem')


sns.scatterplot(data=df_limpo, x='velocidade_vento',y='contagem', ax=axes[1,1], color="blue")
axes[1,1].set_title('Velocidade do Vento vs Contagem')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))

sns.heatmap(df_limpo.corr(numeric_only=True), annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# # Explorando os dados categóricos

# %%
df_limpo.describe(include=[object])
# Out:
#                   data_hora      clima feriado fim_de_semana    estacao
# count                 17414      17414   17414         17414      17414
# unique                17414          6       2             2          4
# top     2017-01-03 23:00:00  Céu limpo     Não           Não  Primavera
# freq                      1       6150   17030         12444       4394

# %%
for col in ['clima', 'feriado', 'fim_de_semana', 'estacao']:
    print(f'Coluna: {col}')
    print(df_limpo[col].unique())
    print("="*15,'\n')
# Out:
# Coluna: clima
# ['Nublado' 'Céu limpo' 'Parcialmente nublado' 'Chuva leve' 'Neve'
#  'Chuva com trovoadas']
# ===============
#
# Coluna: feriado
# ['Não' 'Sim']
# ===============
#
# Coluna: fim_de_semana
# ['Sim' 'Não']
# ===============
#
# Coluna: estacao
# ['Inverno' 'Primavera' 'Verão' 'Outono']
# ===============

# %%
plt.figure(figsize=(8,4))

sns.boxplot(x="feriado",y="contagem", data=df_limpo)
plt.title("Aluguéis de bicicletas em dias normais vs feriado")
plt.xlabel("Feriado")
plt.ylabel("Número de aluguéis")
plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(x="fim_de_semana",y="contagem", data=df_limpo)
plt.title("Aluguéis de bicicletas em dias normais vs finais de semana")
plt.xlabel("Fim de Semana")
plt.ylabel("Número de aluguéis")
plt.show()

# %%
mediana_feriado = df_limpo.groupby('feriado')['contagem'].median()
mediana_fim_de_semana = df_limpo.groupby('fim_de_semana')['contagem'].median()

# %%
mediana_feriado
# Out:
# feriado
# Não    855.0
# Sim    439.5
# Name: contagem, dtype: float64

# %%
mediana_fim_de_semana
# Out:
# fim_de_semana
# Não    927.0
# Sim    619.0
# Name: contagem, dtype: float64

# %%
df_clima = df_limpo.groupby('clima')['contagem'].sum().reset_index().sort_values(by='contagem',ascending=False)

plt.figure(figsize=(6,4))

sns.barplot(data=df_clima, y='clima', x='contagem', hue='clima', palette='Blues_r', orient='h')

plt.title('Bicicletas alugadas por clima')
plt.xlabel('Contagem')
plt.ylabel('')
plt.show()

# %%
df_clima
# Out:
#                   clima  contagem
# 2             Céu limpo   7146847
# 5  Parcialmente nublado   6965558
# 4               Nublado   4243887
# 1            Chuva leve   1526461
# 3                  Neve     15051
# 0   Chuva com trovoadas      8168

# %%
plt.figure(figsize=(8,4))


paleta_cores = {
    'Primavera': 'green',
    'Verão': 'orange',
    'Outono': 'brown',
    'Inverno': 'blue'
}

sns.boxplot(x='estacao', y='contagem', data=df_limpo, hue='estacao', palette=paleta_cores)
plt.title('Aluguéis de bicicleta por estação do ano')
plt.xlabel('Estação do ano')
plt.ylabel('Aluguéis')
plt.show()

# %%
df_limpo.groupby('estacao')['contagem'].median()
# Out:
# estacao
# Inverno       632.0
# Outono        898.0
# Primavera     823.0
# Verão        1214.0
# Name: contagem, dtype: float64

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from scipy) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import mannwhitneyu

primavera = df_limpo[df_limpo['estacao'] == 'Primavera']['contagem']
outono = df_limpo[df_limpo['estacao'] == 'Outono']['contagem']

u_statistic, p_value = mannwhitneyu(primavera,outono, alternative='two-sided')

u_statistic, p_value
# Out:
# (np.float64(9044682.5), np.float64(0.0004762100221646296))

# %% [markdown]
# # Analisando os dados ao longo do tempo

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_hora         17414 non-null  object
#  1   contagem          17414 non-null  int64
#  2   temperatura       17414 non-null  float64
#  3   sensacao_termica  17414 non-null  float64
#  4   umidade           17414 non-null  float64
#  5   velocidade_vento  17414 non-null  float64
#  6   clima             17414 non-null  object
#  7   feriado           17414 non-null  object
#  8   fim_de_semana     17414 non-null  object
#  9   estacao           17414 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 1.5+ MB

# %%
df_data = df_limpo.copy()

# %%
df_data['data_hora'] = pd.to_datetime(df_data['data_hora'])

df_data.head()
# Out:
#             data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0 2015-01-04 00:00:00       182         3.00              2.00     93.0
# 1 2015-01-04 01:00:00       138         2.75              2.25     93.0
# 2 2015-01-04 02:00:00       134         2.50              2.50     96.5
# 3 2015-01-04 03:00:00        72         2.00              2.00    100.0
# 4 2015-01-04 04:00:00        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao
# 0               6.0    Nublado     Não           Sim  Inverno
# 1               5.0  Céu limpo     Não           Sim  Inverno
# 2               0.0  Céu limpo     Não           Sim  Inverno
# 3               0.0  Céu limpo     Não           Sim  Inverno
# 4               6.5  Céu limpo     Não           Sim  Inverno

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_hora         17414 non-null  datetime64[ns]
#  1   contagem          17414 non-null  int64
#  2   temperatura       17414 non-null  float64
#  3   sensacao_termica  17414 non-null  float64
#  4   umidade           17414 non-null  float64
#  5   velocidade_vento  17414 non-null  float64
#  6   clima             17414 non-null  object
#  7   feriado           17414 non-null  object
#  8   fim_de_semana     17414 non-null  object
#  9   estacao           17414 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df_data['mes'] = df_data['data_hora'].dt.month
df_data['horario'] = df_data['data_hora'].dt.hour

# %%
df_data.head()
# Out:
#             data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0 2015-01-04 00:00:00       182         3.00              2.00     93.0
# 1 2015-01-04 01:00:00       138         2.75              2.25     93.0
# 2 2015-01-04 02:00:00       134         2.50              2.50     96.5
# 3 2015-01-04 03:00:00        72         2.00              2.00    100.0
# 4 2015-01-04 04:00:00        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao  mes  horario
# 0               6.0    Nublado     Não           Sim  Inverno    1        0
# 1               5.0  Céu limpo     Não           Sim  Inverno    1        1
# 2               0.0  Céu limpo     Não           Sim  Inverno    1        2
# 3               0.0  Céu limpo     Não           Sim  Inverno    1        3
# 4               6.5  Céu limpo     Não           Sim  Inverno    1        4

# %%
df_data['data_hora'] = df_data['data_hora'].dt.date

df_data.head()
# Out:
#     data_hora  contagem  temperatura  sensacao_termica  umidade  \
# 0  2015-01-04       182         3.00              2.00     93.0
# 1  2015-01-04       138         2.75              2.25     93.0
# 2  2015-01-04       134         2.50              2.50     96.5
# 3  2015-01-04        72         2.00              2.00    100.0
# 4  2015-01-04        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao  mes  horario
# 0               6.0    Nublado     Não           Sim  Inverno    1        0
# 1               5.0  Céu limpo     Não           Sim  Inverno    1        1
# 2               0.0  Céu limpo     Não           Sim  Inverno    1        2
# 3               0.0  Céu limpo     Não           Sim  Inverno    1        3
# 4               6.5  Céu limpo     Não           Sim  Inverno    1        4

# %%
df_data = df_data.rename(columns={ 'data_hora': 'data' })

df_data.head()
# Out:
#          data  contagem  temperatura  sensacao_termica  umidade  \
# 0  2015-01-04       182         3.00              2.00     93.0
# 1  2015-01-04       138         2.75              2.25     93.0
# 2  2015-01-04       134         2.50              2.50     96.5
# 3  2015-01-04        72         2.00              2.00    100.0
# 4  2015-01-04        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao  mes  horario
# 0               6.0    Nublado     Não           Sim  Inverno    1        0
# 1               5.0  Céu limpo     Não           Sim  Inverno    1        1
# 2               0.0  Céu limpo     Não           Sim  Inverno    1        2
# 3               0.0  Céu limpo     Não           Sim  Inverno    1        3
# 4               6.5  Céu limpo     Não           Sim  Inverno    1        4

# %%
df_data['data'] = pd.to_datetime(df_data['data'])

df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 0 to 17413
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data              17414 non-null  datetime64[ns]
#  1   contagem          17414 non-null  int64
#  2   temperatura       17414 non-null  float64
#  3   sensacao_termica  17414 non-null  float64
#  4   umidade           17414 non-null  float64
#  5   velocidade_vento  17414 non-null  float64
#  6   clima             17414 non-null  object
#  7   feriado           17414 non-null  object
#  8   fim_de_semana     17414 non-null  object
#  9   estacao           17414 non-null  object
#  10  mes               17414 non-null  int32
#  11  horario           17414 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(1), object(4)
# memory usage: 1.6+ MB

# %%
df_data.head()
# Out:
#         data  contagem  temperatura  sensacao_termica  umidade  \
# 0 2015-01-04       182         3.00              2.00     93.0
# 1 2015-01-04       138         2.75              2.25     93.0
# 2 2015-01-04       134         2.50              2.50     96.5
# 3 2015-01-04        72         2.00              2.00    100.0
# 4 2015-01-04        47         2.00              2.00     93.0
#
#    velocidade_vento      clima feriado fim_de_semana  estacao  mes  horario
# 0               6.0    Nublado     Não           Sim  Inverno    1        0
# 1               5.0  Céu limpo     Não           Sim  Inverno    1        1
# 2               0.0  Céu limpo     Não           Sim  Inverno    1        2
# 3               0.0  Céu limpo     Não           Sim  Inverno    1        3
# 4               6.5  Céu limpo     Não           Sim  Inverno    1        4

# %%
df_hora = df_data.groupby('horario')['contagem'].sum().reset_index()

plt.figure(figsize=(8,4))

sns.barplot(data=df_hora, x='horario', y='contagem')
plt.title('Bicicletas alugadas por hora')
plt.xlabel('Horário')
plt.ylabel('Contagem')
plt.show()

# %%
df_fim_de_semana = df_data[df_data['fim_de_semana'] == 'Sim']

alugueis_fim_de_semana = df_fim_de_semana.groupby('horario')['contagem'].sum().reset_index()

plt.figure(figsize=(8,4))

sns.barplot(data=alugueis_fim_de_semana, x='horario', y='contagem')
plt.title('Bicicletas alugadas por hora durante o fim de semana')
plt.xlabel('Horário')
plt.ylabel('Contagem')
plt.show()

# %%
df_feriado = df_data[df_data['feriado'] == 'Sim']

alugueis_feriado = df_feriado.groupby('horario')['contagem'].sum().reset_index()

plt.figure(figsize=(8,4))

sns.barplot(data=alugueis_feriado, x='horario', y='contagem')
plt.title('Bicicletas alugadas por hora durante o feriado')
plt.xlabel('Horário')
plt.ylabel('Contagem')
plt.show()

# %%
df_tempo = df_data.groupby('data')['contagem'].sum().reset_index()


plt.figure(figsize=(22,6))

sns.lineplot(data=df_tempo, x='data', y='contagem')
plt.title('Aluguéis ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Número de aluguéis')
plt.show()

# %%
alugueis_mensais = df_data.groupby('mes')['contagem'].sum().reset_index()

plt.figure(figsize=(8,6))

sns.barplot(data=alugueis_mensais, x='mes', y='contagem')
plt.title('Aluguéis de bicicletas por mês')
plt.show()

# %% [markdown]
# # Construindo um modelo preditivo

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (1.1.6)
# Requirement already satisfied: tqdm>=4.36.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from prophet) (4.67.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from prophet) (3.9.2)
# Requirement already satisfied: numpy>=1.15.4 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from prophet) (2.1.3)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from prophet) (1.2.4)
# Requirement already satisfied: pandas>=1.0.4 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from prophet) (2.2.3)
# Requirement already satisfied: holidays<1,>=0.25 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from prophet) (0.61)
# Requirement already satisfied: importlib-resources in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from prophet) (6.4.5)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (11.0.0)
# Requirement already satisfied: cycler>=0.10 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (4.55.0)
# Requirement already satisfied: packaging>=20.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet

# %%
df_prophet = df_data[['data','contagem']].rename(columns={ 'data': 'ds', 'contagem': 'y' })

df_prophet.head()
# Out:
#           ds    y
# 0 2015-01-04  182
# 1 2015-01-04  138
# 2 2015-01-04  134
# 3 2015-01-04   72
# 4 2015-01-04   47

# %%
df_prophet = df_prophet.groupby('ds')['y'].sum().reset_index()

df_prophet
# Out:
#             ds      y
# 0   2015-01-04   9234
# 1   2015-01-05  20372
# 2   2015-01-06  20613
# 3   2015-01-07  21064
# 4   2015-01-08  15601
# ..         ...    ...
# 725 2016-12-30  11566
# 726 2016-12-31  11424
# 727 2017-01-01   6421
# 728 2017-01-02  11823
# 729 2017-01-03  19436
#
# [730 rows x 2 columns]

# %%
import numpy as np

np.random.seed(4587)

modelo = Prophet()

modelo.fit(df_prophet)

futuro = modelo.make_future_dataframe(periods=90, freq='D')

previsao = modelo.predict(futuro)
# Out:
# 18:23:43 - cmdstanpy - INFO - Chain [1] start processing
# 18:23:44 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig1 = modelo.plot(previsao)

# %%
previsao[['ds','yhat','yhat_lower','yhat_upper']]
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 0   2015-01-04  10901.148240   4272.992256  17164.501687
# 1   2015-01-05  15311.232708   8913.287413  22636.582586
# 2   2015-01-06  18014.350866  11829.942639  24414.201504
# 3   2015-01-07  18744.719144  12344.154062  25364.884607
# 4   2015-01-08  19556.191727  12809.812197  26023.639264
# ..         ...           ...           ...           ...
# 815 2017-03-30  27262.740955  20840.917738  34360.842038
# 816 2017-03-31  25490.750990  19305.507172  31997.954460
# 817 2017-04-01  21173.750109  15400.577315  27665.232260
# 818 2017-04-02  20856.740496  14700.917577  27176.730648
# 819 2017-04-03  25249.651434  19148.109285  32106.958345
#
# [820 rows x 4 columns]

# %%
fig2 = modelo.plot_components(previsao)

# %%
df_prophet.shape
# Out:
# (730, 2)

# %%
df_treino = pd.DataFrame()

df_treino['ds'] = df_prophet['ds'][:584]
df_treino['y'] = df_prophet['y'][:584]

# %%
df_teste = pd.DataFrame()

df_teste['ds'] = df_prophet['ds'][584:]
df_teste['y'] = df_prophet['y'][584:]

# %%
np.random.seed(4587)

modelo = Prophet()
modelo.fit(df_treino)

futuro = modelo.make_future_dataframe(periods=150, freq='D')
previsao = modelo.predict(futuro)
# Out:
# 18:23:45 - cmdstanpy - INFO - Chain [1] start processing
# 18:23:45 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig1 = modelo.plot(previsao)

plt.plot(df_teste['ds'], df_teste['y'],'.r')

# %%
fig2 = modelo.plot_components(previsao)

# %%
df_previsao = previsao[['ds','yhat']]

df_comparacao = pd.merge(df_previsao, df_teste, on='ds')

df_comparacao
# Out:
#             ds          yhat      y
# 0   2016-08-10  40646.666399  38430
# 1   2016-08-11  41387.553580  37626
# 2   2016-08-12  39717.735888  40159
# 3   2016-08-13  35936.820545  43041
# 4   2016-08-14  34777.785741  43848
# ..         ...           ...    ...
# 141 2016-12-30  54505.511686  11566
# 142 2016-12-31  50724.596343  11424
# 143 2017-01-01  49565.561539   6421
# 144 2017-01-02  53551.536790  11823
# 145 2017-01-03  55713.285077  19436
#
# [146 rows x 3 columns]

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(df_comparacao['y'], df_comparacao['yhat'])
rmse = np.sqrt(mse)

print(f'MSE: {mse}, RMSE: {rmse}')
# Out:
# MSE: 466132050.6184666, RMSE: 21590.09149166503

# %% [markdown]
# # Melhorando as previsões

# %%
np.random.seed(4587)

modelo = Prophet(
    yearly_seasonality=True
)
modelo.fit(df_treino)

futuro = modelo.make_future_dataframe(periods=150, freq='D')
previsao = modelo.predict(futuro)
# Out:
# 18:23:48 - cmdstanpy - INFO - Chain [1] start processing
# 18:23:48 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig1 = modelo.plot(previsao)

plt.plot(df_teste['ds'], df_teste['y'], '.r')

# %%
fig2 = modelo.plot_components(previsao)

# %%
df_previsao = previsao[['ds','yhat']]

df_comparacao = pd.merge(df_previsao, df_teste, on='ds')

mse = mean_squared_error(df_comparacao['y'], df_comparacao['yhat'])
rmse = np.sqrt(mse)

print(f'MSE: {mse}, RMSE: {rmse}')
# Out:
# MSE: 38623883.499975376, RMSE: 6214.8116222437

# %%
df_prophet
# Out:
#             ds      y
# 0   2015-01-04   9234
# 1   2015-01-05  20372
# 2   2015-01-06  20613
# 3   2015-01-07  21064
# 4   2015-01-08  15601
# ..         ...    ...
# 725 2016-12-30  11566
# 726 2016-12-31  11424
# 727 2017-01-01   6421
# 728 2017-01-02  11823
# 729 2017-01-03  19436
#
# [730 rows x 2 columns]

# %%
np.random.seed(4587)

modelo = Prophet()

modelo.fit(df_prophet)

futuro = modelo.make_future_dataframe(periods=0)

previsao = modelo.predict(futuro)
# Out:
# 18:23:49 - cmdstanpy - INFO - Chain [1] start processing
# 18:23:49 - cmdstanpy - INFO - Chain [1] done processing

# %%
sem_outliers = df_prophet[(df_prophet['y'] > previsao['yhat_lower']) & (df_prophet['y'] < previsao['yhat_upper'])]

# %%
sem_outliers
# Out:
#             ds      y
# 0   2015-01-04   9234
# 1   2015-01-05  20372
# 2   2015-01-06  20613
# 3   2015-01-07  21064
# 4   2015-01-08  15601
# ..         ...    ...
# 725 2016-12-30  11566
# 726 2016-12-31  11424
# 727 2017-01-01   6421
# 728 2017-01-02  11823
# 729 2017-01-03  19436
#
# [631 rows x 2 columns]

# %%
df_treino = pd.DataFrame()

df_treino['ds'] = sem_outliers['ds'][:505]
df_treino['y'] = sem_outliers['y'][:505]

# %%
df_teste = pd.DataFrame()

df_teste['ds'] = sem_outliers['ds'][505:]
df_teste['y'] = sem_outliers['y'][505:]

# %%
np.random.seed(4587)

modelo_sem_outliers = Prophet(
    yearly_seasonality=True
)

modelo_sem_outliers.fit(df_treino)

futuro = modelo_sem_outliers.make_future_dataframe(periods=150,freq='D')

previsao = modelo_sem_outliers.predict(futuro)
# Out:
# 18:23:49 - cmdstanpy - INFO - Chain [1] start processing
# 18:23:49 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig1 = modelo_sem_outliers.plot(previsao)
plt.plot(df_teste['ds'], df_teste['y'], '.r')

# %%
df_previsao = previsao[['ds','yhat']]

df_comparacao = pd.merge(df_previsao, df_teste, on='ds')

mse = mean_squared_error(df_comparacao['y'], df_comparacao['yhat'])
rmse = np.sqrt(mse)

print(f'MSE: {mse}, RMSE: {rmse}')
# Out:
# MSE: 15672925.764235971, RMSE: 3958.904616713564

# %%
np.random.seed(4587)

modelo_sem_outliers = Prophet(
    yearly_seasonality=True
)

modelo_sem_outliers.fit(df_treino)

futuro = modelo_sem_outliers.make_future_dataframe(periods=365,freq='D')

previsao = modelo_sem_outliers.predict(futuro)
# Out:
# 18:23:50 - cmdstanpy - INFO - Chain [1] start processing
# 18:23:50 - cmdstanpy - INFO - Chain [1] done processing

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /home/gabriel/alura/data-science-temporal-series/venv/lib/python3.10/site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scatter(x=[1, 2, 3], y=[10, 20, 30]))
fig.show()
# Out:
# <div>                            <div id="709855e7-6259-479d-9714-8018c0135f53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("709855e7-6259-479d-9714-8018c0135f53")) {                    Plotly.newPlot(                        "709855e7-6259-479d-9714-8018c0135f53",                        [{"x":[1,2,3],"y":[10,20,30],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0, ...
#
# var gd = document.getElementById('709855e7-6259-479d-9714-8018c0135f53');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# /

# %%
from prophet.plot import plot_plotly

# %%
fig = plot_plotly(modelo_sem_outliers,previsao)
fig.show()
